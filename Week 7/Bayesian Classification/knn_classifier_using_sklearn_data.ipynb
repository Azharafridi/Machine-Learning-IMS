# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay, f1_score
import matplotlib.pyplot as plt

# %%
# Generate synthetic data
X, y = make_classification(
    n_features=6,
    n_classes=3,
    n_samples=800,
    n_informative=2,
    random_state=1,
    n_clusters_per_class=1,
)

# %%
# Plot the data
plt.scatter(X[:, 0], X[:, 1], c=y, marker="*")
plt.show()

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=125
)

# %%
# Build a KNN Classifier
knn_model = KNeighborsClassifier(n_neighbors=5)

# %%
# Model training
knn_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# Predict Output for a sample
predicted_knn = knn_model.predict([X_test[6]])

# %%
print("Actual Value:", y_test[6])
print("Predicted Value (KNN):", predicted_knn[0])
# Out:
# Actual Value: 0
# Predicted Value (KNN): 0

# %%
# Evaluate the KNN model
y_pred_knn = knn_model.predict(X_test)
accuracy_knn = accuracy_score(y_pred_knn, y_test)
f1_knn = f1_score(y_pred_knn, y_test, average="weighted")
print("KNN Accuracy:", accuracy_knn)
print("KNN F1 Score:", f1_knn)
# Out:
# KNN Accuracy: 0.821969696969697
# KNN F1 Score: 0.8225416798033206

# %%
# Confusion matrix for KNN
labels = [0, 1, 2]
cm_knn = confusion_matrix(y_test, y_pred_knn, labels=labels)
disp_knn = ConfusionMatrixDisplay(confusion_matrix=cm_knn, display_labels=labels)
disp_knn.plot()
plt.title("Confusion Matrix - KNN")
plt.show()
